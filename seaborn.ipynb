# %%
#pip install seaborn
import seaborn as sns
print(sns.__version__)
# Out:
# 0.13.2

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips_data=sns.load_dataset('tips')
tips_data
daywise_mean = tips_data.groupby('day').mean(numeric_only=True)
print(daywise_mean)
# Out:
#       total_bill       tip      size
# day
# Thur   17.682742  2.771452  2.451613
# Fri    17.151579  2.734737  2.105263
# Sat    20.441379  2.993103  2.517241
# Sun    21.410000  3.255132  2.842105
# C:\Users\deepa\AppData\Local\Temp\ipykernel_3024\114679401.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   daywise_mean = tips_data.groupby('day').mean(numeric_only=True)

# %%
sns.barplot(tips_data,x='day',y='tip')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.barplot(tips_data,x='sex',y='tip',estimator='mean',hue='day',palette="dark:salmon_r")
# Out:
# <Axes: xlabel='sex', ylabel='tip'>
